# %%
# Put pyACC in the Python Path
import sys
sys.path.append('../')

# Import the Logger
from pyACC.helpers import Logger

# %%
# Set the logger

logger = Logger("Alfonso@pyACC")

# %%
# This is a normal example

logger("Hello World!")
# Out:
# 2025-03-04 21:26:24.120056 :: Alfonso@pyACC :: INFO :: Hello World!

# %%
# This is a warning example
logger.warning("This is a warning")
# Out:
# 2025-03-04 21:26:36.802329 :: Alfonso@pyACC :: WARNING :: This is a warning

# %%
# This is an error example
logger.error("This is an error")
# Out:
# 2025-03-04 21:26:45.716388 :: Alfonso@pyACC :: ERROR :: This is an error

# %%
# This is an error example that raises an exception
logger.error("This is an error with an exception", ErrorType=ValueError)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # This is an error example that raises an exception
# ----> 2 logger.error("This is an error with an exception", ErrorType=ValueError)
#
# File ~/Work/astrocosmolib/demo/../pyACC/helpers/logger.py:79, in Logger.error(self, message, ErrorType)
#      77     print(msg)
#      78 else:
# ---> 79     raise(ErrorType(msg))
#
# ValueError: 2025-03-04 21:27:41.614383 :: Alfonso@pyACC :: ERROR :: This is an error with an exception
